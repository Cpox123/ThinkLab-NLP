# %%
# !pip install gdown

# %%
import gdown
import os

# Replace with your tf_model.t5 file ID from Google Drive
file_id = '1JvmGJPC0Xr7qTK1eZxkXP0zjrD-aD64P'
url = f'https://drive.google.com/uc?id={file_id}'

# Where the model will be saved
output = 'models/tf_model.t5'

os.makedirs('models', exist_ok=True)

print("Downloading BERT model... this may take a while.")
gdown.download(url, output, quiet=False)
print("Download complete! Model saved to:", output)
# Out:
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1JvmGJPC0Xr7qTK1eZxkXP0zjrD-aD64P
# From (redirected): https://drive.google.com/uc?id=1JvmGJPC0Xr7qTK1eZxkXP0zjrD-aD64P&confirm=t&uuid=80c8a6be-b30b-4129-a02f-896ae8cc632c
# To: /content/models/tf_model.t5
# 100%|██████████| 438M/438M [00:07<00:00, 57.0MB/s]
# Download complete! Model saved to: models/tf_model.t5
